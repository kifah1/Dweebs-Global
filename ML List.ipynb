# %% [markdown]
# # <font color=blue>list of all the ML algorithms:</font>
#
# ## Regression Algorithms
# 1.	Ordinary Least Squares Regression (OLSR)
# 2.	Linear Regression
# 3.	Logistic Regression
# 4.	Stepwise Regression
# 5.	Multivariate Adaptive Regression Splines (MARS)
# 6.	Locally Estimated Scatterplot Smoothing (LOESS)
#
# ## Instance-based Algorithms
# 1.	K-Nearest Neighbor (KNN)
# 2.	Learning Vector Quantization (LVQ)
# 3.	Self-Organizing Map (SOM)
# 4.	Locally Weighted Learning (LWL)
# 5.	Support Vector Machines (SVM)
#
# ## Regularization Algorithms
# 1.	Ridge Regression
# 2.	Least Absolute Shrinkage and Selection Operator (LASSO)
# 3.	Elastic Net
# 4.	Least-Angle Regression (LARS)
#
# ## Decision Tree Algorithms
# 1.	Classification and Regression Tree (CART)
# 2.	Iterative Dichotomiser 3 (ID3)
# 3.	C4.5 and C5.0 algorithms
# 4.	Chi-squared Automatic Interaction Detection (CHAID)
# 5.	Decision Stump
# 6.	M5
# 7.	Conditional Decision Trees
# 8.	Random forest
# 9.	SLIQ
#
# ## Bayesian Algorithms
# 1.	Naive Bayes
# 2.	Gaussian Naive Bayes
# 3.	Multinomial Naive Bayes
# 4.	Averaged One-Dependence Estimators (AODE)
# 5.	Bayesian Belief Network (BBN)
# 6.	Bayesian Network (BN)
# 7.	Bayesian knowledge base
#
# ## Clustering Algorithms
# 1.	k-Means
# 2.	k-Medians
# 3.	Expectation Maximisation (EM)
# 4.	Hierarchical Clustering
# 5.	Mean-shift
# 6.	OPTICS algorithm
# 7.	Fuzzy clustering
# 8.	BIRCH
# 9.	DBSCAN
#
# ## Association Rule Learning Algorithms
# 1.	Apriori algorithm
# 2.	Eclat algorithm
# 3.	FP-growth algorithm
#
# ## Artificial Neural Network Algorithms
# 1.	Perceptron
# 2.	Multilayer Perceptrons (MLP)
# 3.	Back-Propagation
# 4.	Stochastic Gradient Descent
# 5.	Hopfield Network
# 6.	Radial Basis Function Network (RBFN)
#
# ## Deep Learning Algorithms
# 1.	Convolutional Neural Network (CNN)
# 2.	Recurrent Neural Networks (RNNs)
# 3.	Long Short-Term Memory Networks (LSTMs)
# 4.	Stacked Auto-Encoders
# 5.	Deep Boltzmann Machine (DBM)
# 6.	Deep Belief Networks (DBN)
# 7.	Hierarchical temporal memory
# 8.	Generative Adversarial Networks
#
# ## Dimensionality Reduction Algorithms
# 1.	Canonical correlation analysis (CCA)
# 2.	Factor analysis
# 3.	Feature extraction
# 4.	Feature selection
# 5.	Independent component analysis (ICA)
# 6.	Principal Component Analysis (PCA)
# 7.	Principal Component Regression (PCR)
# 8.	Partial Least Squares Regression (PLSR)
# 9.	Sammon Mapping
# 10.	Multidimensional Scaling (MDS)
# 11.	Non-negative matrix factorization (NMF)
# 12.	Projection Pursuit
# 13.	Linear Discriminant Analysis (LDA)
# 14.	Mixture Discriminant Analysis (MDA)
# 15.	Quadratic Discriminant Analysis (QDA)
# 16.	Flexible Discriminant Analysis (FDA)
# 17.	t-distributed stochastic neighbor embedding (t-SNE)
#
# ## Ensemble Algorithms
# 1.	Boosting
# 2.	Bootstrapped Aggregation (Bagging)
# 3.	AdaBoost
# 4.	Ensemble averaging
# 5.	Weighted Average (Blending)
# 6.	Stacked Generalization (Blending)
# 7.	Stacked Generalization (Stacking)
# 8.	Gradient Boosting Machines (GBM)
# 9.	Gradient boosted decision tree (GBDT)
# 10.	Gradient Boosted Regression Trees (GBRT)
# 11.	Random Forest
#
# ## Meta Algorithms
# 1.	Inductive bias
# 2.	Metadata
#
# ## Reinforcement learning Algorithms
# 1.	Q-learning
# 2.	State–action–reward–state–action (SARSA)
# 3.	Temporal difference learning (TD)
# 4.	Learning Automata
#
# ## Supervised learning
# 1.	AODE
# 2.	Artificial neural network
# 3.	Apriori algorithm
# 4.	Eclat algorithm
# 5.	Case-based reasoning
# 6.	Gaussian process regression
# 7.	Gene expression programming
# 8.	Group method of data handling (GMDH)
# 9.	Inductive logic programming
# 10.	Instance-based learning
# 11.	Lazy learning
# 12.	Learning Automata
# 13.	Learning Vector Quantization
# 14.	Logistic Model Tree
# 15.	Nearest Neighbor Algorithm
# 16.	Analogical modeling
# 17.	Probably approximately correct learning (PAC)
# 18.	Ripple down rules, a knowledge acquisition methodology
# 19.	Symbolic machine learning algorithms
# 20.	Support vector machines
# 21.	Random Forests
# 22.	Bootstrap aggregating (bagging)
# 23.	Boosting (meta-algorithm)
# 24.	Ordinal classification
# 25.	Information fuzzy networks (IFN)
# 26.	Conditional Random Field
# 27.	ANOVA
# 28.	Quadratic classifiers
# 29.	k-nearest neighbor
# 30.	SPRINT
# 31.	Naive Bayes
# 32.	Hierarchical hidden Markov model
#
# ## Unsupervised learning
# 1.	Expectation-maximization algorithm
# 2.	Vector Quantization
# 3.	Generative topographic map
# 4.	Information bottleneck method
#
# ## Semi-supervised learning
# 1.	Active learning
# 2.	Generative models
# 3.	Low-density separation
# 4.	Graph-based methods
# 5.	Co-training
# 6.	Transduction
#
# ## Classifiers
# 1.	Probabilistic classifier
# 2.	Naive Bayes classifier
# 3.	Binary classifier
# 4.	Linear classifier
# 5.	Hierarchical classifier
#
# ## Linear classifier
# 1.	Fisher's linear discriminant
# 2.	Linear regression
# 3.	Logistic regression
# 4.	Multinomial logistic regression
# 5.	Naive Bayes classifier
# 6.	Perceptron
# 7.	Support vector machine
#
# ## Other Machine Learning Algorithms
# 1.	Feature selection algorithms
# 2.	Algorithm accuracy evaluation
# 3.	Performance measures
# 4.	Optimization algorithms
# 5.	Computational intelligence (evolutionary algorithms, etc.)
# 6.	Computer Vision (CV)
# 7.	Natural Language Processing (NLP)
# 8.	Recommender Systems
# 9.	Reinforcement Learning
# 10.	Graphical Models
